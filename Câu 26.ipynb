# %%
def check_number(num):
    if num == 1 or num == 0:
        return False
    prime = [True for loop in range(num)]
    prime[0] = prime[1] = False
    for loop in range(2, num):
        if prime[loop]:
            for j in range(loop * 2, num, loop):
                prime[j] = False
    for loop in range(1, int(num / 2) + 1):
        if prime[loop] and num % loop == 0 and num % (loop ** 2) == 0:
            print(num, "chia hết cho:", loop, " và ", loop ** 2)


if __name__ == '__main__':
    num_N = int(input("Nhập 0 < B < 10000: "))
    while num_N <= 0 or num_N >= 10000:
        num_N = int(input("Nhập Lại 0 < B < 10000: "))

    for i in range(num_N):
        check_number(i)
# Out:
# Nhập 0 < B < 10000:  500
# 4 chia hết cho: 2  và  4
# 8 chia hết cho: 2  và  4
# 9 chia hết cho: 3  và  9
# 12 chia hết cho: 2  và  4
# 16 chia hết cho: 2  và  4
# 18 chia hết cho: 3  và  9
# 20 chia hết cho: 2  và  4
# 24 chia hết cho: 2  và  4
# 25 chia hết cho: 5  và  25
# 27 chia hết cho: 3  và  9
# 28 chia hết cho: 2  và  4
# 32 chia hết cho: 2  và  4
# 36 chia hết cho: 2  và  4
# 36 chia hết cho: 3  và  9
# 40 chia hết cho: 2  và  4
# 44 chia hết cho: 2  và  4
# 45 chia hết cho: 3  và  9
# 48 chia hết cho: 2  và  4
# 49 chia hết cho: 7  và  49
# 50 chia hết cho: 5  và  25
# 52 chia hết cho: 2  và  4
# 54 chia hết cho: 3  và  9
# 56 chia hết cho: 2  và  4
# 60 chia hết cho: 2  và  4
# 63 chia hết cho: 3  và  9
# 64 chia hết cho: 2  và  4
# 68 chia hết cho: 2  và  4
# 72 chia hết cho: 2  và  4
# 72 chia hết cho: 3  và  9
# 75 chia hết cho: 5  và  25
# 76 chia hết cho: 2  và  4
# 80 chia hết cho: 2  và  4
# 81 chia hết cho: 3  và  9
# 84 chia hết cho: 2  và  4
# 88 chia hết cho: 2  và  4
# 90 chia hết cho: 3  và  9
# 92 chia hết cho: 2  và  4
# 96 chia hết cho: 2  và  4
# 98 chia hết cho: 7  và  49
# 99 chia hết cho: 3  và  9
# 100 chia hết cho: 2  và  4
# 100 chia hết cho: 5  và  25
# 104 chia hết cho: 2  và  4
# 108 chia hết cho: 2  và  4
# 108 chia hết cho: 3  và  9
# 112 chia hết cho: 2  và  4
# 116 chia hết cho: 2  và  4
# 117 chia hết cho: 3  và  9
# 120 chia hết cho: 2  và  4
# 121 chia hết cho: 11  và  121
# 124 chia hết cho: 2  và  4
# 125 chia hết cho: 5  và  25
# 126 chia hết cho: 3  và  9
# 128 chia hết cho: 2  và  4
# 132 chia hết cho: 2  và  4
# 135 chia hết cho: 3  và  9
# 136 chia hết cho: 2  và  4
# 140 chia hết cho: 2  và  4
# 144 chia hết cho: 2  và  4
# 144 chia hết cho: 3  và  9
# 147 chia hết cho: 7  và  49
# 148 chia hết cho: 2  và  4
# 150 chia hết cho: 5  và  25
# 152 chia hết cho: 2  và  4
# 153 chia hết cho: 3  và  9
# 156 chia hết cho: 2  và  4
# 160 chia hết cho: 2  và  4
# 162 chia hết cho: 3  và  9
# 164 chia hết cho: 2  và  4
# 168 chia hết cho: 2  và  4
# 169 chia hết cho: 13  và  169
# 171 chia hết cho: 3  và  9
# 172 chia hết cho: 2  và  4
# 175 chia hết cho: 5  và  25
# 176 chia hết cho: 2  và  4
# 180 chia hết cho: 2  và  4
# 180 chia hết cho: 3  và  9
# 184 chia hết cho: 2  và  4
# 188 chia hết cho: 2  và  4
# 189 chia hết cho: 3  và  9
# 192 chia hết cho: 2  và  4
# 196 chia hết cho: 2  và  4
# 196 chia hết cho: 7  và  49
# 198 chia hết cho: 3  và  9
# 200 chia hết cho: 2  và  4
# 200 chia hết cho: 5  và  25
# 204 chia hết cho: 2  và  4
# 207 chia hết cho: 3  và  9
# 208 chia hết cho: 2  và  4
# 212 chia hết cho: 2  và  4
# 216 chia hết cho: 2  và  4
# 216 chia hết cho: 3  và  9
# 220 chia hết cho: 2  và  4
# 224 chia hết cho: 2  và  4
# 225 chia hết cho: 3  và  9
# 225 chia hết cho: 5  và  25
# 228 chia hết cho: 2  và  4
# 232 chia hết cho: 2  và  4
# 234 chia hết cho: 3  và  9
# 236 chia hết cho: 2  và  4
# 240 chia hết cho: 2  và  4
# 242 chia hết cho: 11  và  121
# 243 chia hết cho: 3  và  9
# 244 chia hết cho: 2  và  4
# 245 chia hết cho: 7  và  49
# 248 chia hết cho: 2  và  4
# 250 chia hết cho: 5  và  25
# 252 chia hết cho: 2  và  4
# 252 chia hết cho: 3  và  9
# 256 chia hết cho: 2  và  4
# 260 chia hết cho: 2  và  4
# 261 chia hết cho: 3  và  9
# 264 chia hết cho: 2  và  4
# 268 chia hết cho: 2  và  4
# 270 chia hết cho: 3  và  9
# 272 chia hết cho: 2  và  4
# 275 chia hết cho: 5  và  25
# 276 chia hết cho: 2  và  4
# 279 chia hết cho: 3  và  9
# 280 chia hết cho: 2  và  4
# 284 chia hết cho: 2  và  4
# 288 chia hết cho: 2  và  4
# 288 chia hết cho: 3  và  9
# 289 chia hết cho: 17  và  289
# 292 chia hết cho: 2  và  4
# 294 chia hết cho: 7  và  49
# 296 chia hết cho: 2  và  4
# 297 chia hết cho: 3  và  9
# 300 chia hết cho: 2  và  4
# 300 chia hết cho: 5  và  25
# 304 chia hết cho: 2  và  4
# 306 chia hết cho: 3  và  9
# 308 chia hết cho: 2  và  4
# 312 chia hết cho: 2  và  4
# 315 chia hết cho: 3  và  9
# 316 chia hết cho: 2  và  4
# 320 chia hết cho: 2  và  4
# 324 chia hết cho: 2  và  4
# 324 chia hết cho: 3  và  9
# 325 chia hết cho: 5  và  25
# 328 chia hết cho: 2  và  4
# 332 chia hết cho: 2  và  4
# 333 chia hết cho: 3  và  9
# 336 chia hết cho: 2  và  4
# 338 chia hết cho: 13  và  169
# 340 chia hết cho: 2  và  4
# 342 chia hết cho: 3  và  9
# 343 chia hết cho: 7  và  49
# 344 chia hết cho: 2  và  4
# 348 chia hết cho: 2  và  4
# 350 chia hết cho: 5  và  25
# 351 chia hết cho: 3  và  9
# 352 chia hết cho: 2  và  4
# 356 chia hết cho: 2  và  4
# 360 chia hết cho: 2  và  4
# 360 chia hết cho: 3  và  9
# 361 chia hết cho: 19  và  361
# 363 chia hết cho: 11  và  121
# 364 chia hết cho: 2  và  4
# 368 chia hết cho: 2  và  4
# 369 chia hết cho: 3  và  9
# 372 chia hết cho: 2  và  4
# 375 chia hết cho: 5  và  25
# 376 chia hết cho: 2  và  4
# 378 chia hết cho: 3  và  9
# 380 chia hết cho: 2  và  4
# 384 chia hết cho: 2  và  4
# 387 chia hết cho: 3  và  9
# 388 chia hết cho: 2  và  4
# 392 chia hết cho: 2  và  4
# 392 chia hết cho: 7  và  49
# 396 chia hết cho: 2  và  4
# 396 chia hết cho: 3  và  9
# 400 chia hết cho: 2  và  4
# 400 chia hết cho: 5  và  25
# 404 chia hết cho: 2  và  4
# 405 chia hết cho: 3  và  9
# 408 chia hết cho: 2  và  4
# 412 chia hết cho: 2  và  4
# 414 chia hết cho: 3  và  9
# 416 chia hết cho: 2  và  4
# 420 chia hết cho: 2  và  4
# 423 chia hết cho: 3  và  9
# 424 chia hết cho: 2  và  4
# 425 chia hết cho: 5  và  25
# 428 chia hết cho: 2  và  4
# 432 chia hết cho: 2  và  4
# 432 chia hết cho: 3  và  9
# 436 chia hết cho: 2  và  4
# 440 chia hết cho: 2  và  4
# 441 chia hết cho: 3  và  9
# 441 chia hết cho: 7  và  49
# 444 chia hết cho: 2  và  4
# 448 chia hết cho: 2  và  4
# 450 chia hết cho: 3  và  9
# 450 chia hết cho: 5  và  25
# 452 chia hết cho: 2  và  4
# 456 chia hết cho: 2  và  4
# 459 chia hết cho: 3  và  9
# 460 chia hết cho: 2  và  4
# 464 chia hết cho: 2  và  4
# 468 chia hết cho: 2  và  4
# 468 chia hết cho: 3  và  9
# 472 chia hết cho: 2  và  4
# 475 chia hết cho: 5  và  25
# 476 chia hết cho: 2  và  4
# 477 chia hết cho: 3  và  9
# 480 chia hết cho: 2  và  4
# 484 chia hết cho: 2  và  4
# 484 chia hết cho: 11  và  121
# 486 chia hết cho: 3  và  9
# 488 chia hết cho: 2  và  4
# 490 chia hết cho: 7  và  49
# 492 chia hết cho: 2  và  4
# 495 chia hết cho: 3  và  9
# 496 chia hết cho: 2  và  4
